# %% [markdown]
# <a href="https://colab.research.google.com/github/AbiSyaibah/Data-Science/blob/main/Visualizing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Setup**

# %%
import pandas as pd
df=pd.read_csv("avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# Kita ingin melihat data albany sitiap tahun

# %%
#membuat pandas mengenali date sebagai waktu
df['Date']=pd.to_datetime(df['Date'])

# %%
#mengambil data untuk albany saja
albany_df=df[df['region']=="Albany"]

#mengubah date menjadi index data
albany_df.set_index("Date",inplace=True)

# %%
#melihat date sudah menjadi index data
albany_df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# ...

# %%
#memplot data
albany_df['AveragePrice'].plot()

# %%
albany_df['AveragePrice'].head(25)
# Out:
# Date
# 2015-12-27    1.33
# 2015-12-20    1.35
# 2015-12-13    0.93
# 2015-12-06    1.08
# 2015-11-29    1.28
# 2015-11-22    1.26
# 2015-11-15    0.99
# 2015-11-08    0.98
# 2015-11-01    1.02
# 2015-10-25    1.07
# 2015-10-18    1.12
# 2015-10-11    1.28
# 2015-10-04    1.31
# 2015-09-27    0.99
# 2015-09-20    1.33
# 2015-09-13    1.28
# 2015-09-06    1.11
# 2015-08-30    1.07
# 2015-08-23    1.34
# 2015-08-16    1.33
# 2015-08-09    1.12
# 2015-08-02    1.45
# 2015-07-26    1.11
# 2015-07-19    1.26
# 2015-07-12    1.05
# Name: AveragePrice, dtype: float64

# %%
#membuat plot lebih smooth dengan rolling
albany_df['AveragePrice'].rolling(25).mean().plot()

#data masih belum rapi

# %% [markdown]
# Sesuatu mungkin salah, mari kita urutkan lagi datanya

# %%
albany_df.sort_index(inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:6393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().sort_index(

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()
#we got a nice graph

# %%
#buat kolom baru dari data di atas
albany_df['price25ma']=albany_df['AveragePrice'].rolling(25).mean()
# Out:
# <ipython-input-12-234193804eac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df['price25ma']=albany_df['AveragePrice'].rolling(25).mean()

# %%
#drop all Nan in df
albany_df.dropna().head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# Date
# 2015-03-29          39          1.93       1082.44    24.75    173.26   0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22  89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66  93.76
# 2015-04-05          38          1.93       1526.10    15.75    202.52   0.00
# 2015-04-12          37          1.76       1634.59    51.75     93.38   0.00
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
# 2015-04-05     1307.83     1307.83        0.00         0.00       organic
# 2015-04-12     1489.46     1489.46        0.00         0.00       organic
#
#             year  region  price25ma
# Date
# ...

# %% [markdown]
# 8. Graph DF
# kita ingin memplot setiap negara di df

# %%
df=pd.read_csv("avocado.csv")

# %%
df=df.copy()[df['type']=='organic']

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.sort_values(by='Date', ascending=True, inplace=True)

# %%
graph_df=pd.DataFrame()

for region in df['region'].unique():
  print(region)
  region_df=df.copy()[df['region']==region]
  region_df.set_index('Date',inplace=True)
  region_df.sort_index(inplace=True)
  region_df[f"{region}_price25ma"]=region_df['AveragePrice'].rolling(25).mean()

  if graph_df.empty:
    graph_df=region_df[[f"{region}_price25ma"]] #untuk mengubahnya jadi dataframe perlu 2 braket, ex: region_df[["Column1","Column2"]]
  else:
    graph_df=graph_df.join(region_df[f"{region}_price25ma"])
# Out:
# California
# Charlotte
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# Louisville
# Orlando
# Southeast
# Jacksonville
# StLouis
# WestTexNewMexico
# MiamiFtLauderdale
# TotalUS
# Nashville
# Northeast
# Atlanta
# Tampa
# Midsouth
# BaltimoreWashington
# NorthernNewEngland
# West
# Syracuse
# HartfordSpringfield
# Boise
# CincinnatiDayton
# Sacramento
# Roanoke
# Denver
# SanDiego
# GreatLakes
# RichmondNorfolk
# DallasFtWorth
# SanFrancisco
# Pittsburgh
# RaleighGreensboro
# Seattle
# GrandRapids
# HarrisburgScranton
# NewOrleansMobile
# NewYork
# Portland
# Detroit
# Albany
# SouthCentral
# Columbus
# Plains
# Chicago
# Houston
# SouthCarolina
# Indianapolis

# %%
graph_df.dropna().plot(figsize=(8,5), legend=False);
